# %% [markdown]
# # Результат ревью V2:
#
# Максим, после правки финального вывода красных комментариев в твоей работе более нет. Соответственно нет и никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня прямо сейчас.
#
# ПРОЕКТ ПРИНЯТ!
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s Повторюсь, что для дальнейшего совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/.
#
# p.p.s Я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.

# %% [markdown]
# Привет Максим!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике (Клиника Кивач, республика Карелия). Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %% [markdown]
# Для проверки данной зависимости необходимо сделать срез по столбцам 'children' и 'debt' и узнать процент задолженности по в каждой категории столбца 'children'.

# %%
data_relationship_children = data[['children', 'debt']] # для получения необходимых данных я сделал срез по двум столбцам
data_relationship_children_d1 = data_relationship_children.loc[data_relationship_children['debt'] == 1][['children','debt']] # здесь я выделил таблицу с условием, где имеется задолженность
data_relationship_children_d1 = data_relationship_children_d1.groupby('children')['debt'].value_counts() # сгруппировал по столбцу children и подсчитал количество выдааных кредитов по заемщикам 
children_d1_frame = data_relationship_children_d1.to_frame() # привел объект series к объекту dataframe

data_relationship_children_d0 = data_relationship_children.loc[data_relationship_children['debt'] == 0][['children','debt']] # сделал тоже самое, что и выше, только по условию, где задолженности нет
data_relationship_children_d0 = data_relationship_children_d0.groupby('children')['debt'].value_counts()
сhildren_d0_frame = data_relationship_children_d0.to_frame()

debt_group = сhildren_d0_frame.merge(children_d1_frame, on='children', how='left') # объединил две таблицы в одну по столбцу children
debt_group.rename(columns={'children':'кол-во детей','debt_x': 'задолж нет', 'debt_y': 'задолж есть'}, inplace=True) # для читаемости переименовал столбцы
debt_group = debt_group.fillna(0) # заменил все пропуски на 0
debt_group['задолж есть'] = debt_group[['задолж есть']].astype(int) # привел столбец к типу integer для того, чтобы убрать ненужные нули

def percent(row): # объявил функцию для подлсчета процента задолженности по кредитам
    row = row['задолж есть']/(row['задолж есть']+row['задолж нет'])*100
    return row

debt_group['% задолж'] = debt_group.apply(percent, axis = 1) # добавил к таблице столбец с процентами задолженности по кредитам

try:
    print(debt_group.sort_values(by = '% задолж', ascending=True))
except:
    print('ошибка')
# Out:
#           задолж нет  задолж есть  % задолж
# children
# 5                  9            0  0.000000
# 0              13028         1063  7.543822
# 3                303           27  8.181818
# 1               4364          444  9.234609
# 2               1858          194  9.454191
# 4                 37            4  9.756098

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Максим - очень сложно. Да, результат ты получаешь верный. И выводы делаешь верные, молодец! Но сложно. для того, чтобы ответить на вопрос этого задания действительно нужна либо функция groupby или pivot_table. Но вот метод loc, объединение merge - не нужны. Без них можно. Весь код этой ячейки можно уложить в одну короткую строку кода, длинной меньше 30 символов. Есть более длинный, более прямолинейный вариант, но он тоже - 2-3 строки.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Максим, думал, думал и решил ещё один комментарий тебе в помощь написать .... Итак, у нас очень "многословно" получилось. Ты вроде бы и используешь groupby, но помимо его ещё делаешь много разных (в принципе понятных мне, но не очень нужных вещей). А ведь именно groupby (или pivot_table) здесь ключ к ответу на вопрос буквально в 2-3 строки.
#
# Напишу словами, а ты попытайся на следующей итерации сделать это. Итак,
#
# 1. (первая строка кода) группируешь детей (children) по столбцу долг (debt)
#
# 2. агрегируешь долг по 2м функциям sum (здесь будут задолжники по соответствующей группе) и count (здесь будут все взявшие кредит в этой группе)
#
# 3. (вторая строка кода) делить всех в группе на должников в группе - получаешь процент задолжников
#
# Сравниваешь проценты, пишешь вывод.
# </div>

# %% [markdown]
# **Вывод:** на основании полученных данных можно сделать вывод о небольшой корреляции в 2% между количеством детей у заемщика и возвратом кредита в срок. Так, люди у которых нет детей допускают просрочку кредита реже, чем те, у кого они есть. Но количество детей не сильно влияет на разброс процента задолженности по кредитам. Однако, в данном исследовании имеется статистический выброс - у людей с пятью детьми просрочек по кредитам нет. Если посмотреть на выборку по данному показателю, становится очевидно, что выборка по заемщикам с пятью детьми слишком мала для учёта - их всего 9, пртив тех же бездетных, их - 14091.
# Поэтому, заемщиков, у которых 5 детей, на данном этапе нельзя включать в скоринговую модель.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, конечно «разбег» между "цифрами" в наших данных мал. Возможно, что в рамках имеющихся данных сделать вывод о том, что семьи с детьми относительно семей без оных имеют какие-то задержки в выплатах кредитов нельзя. Слишком уж близки доли, чуть измениться выборка и значения могут измениться в другую сторону. То есть можно сделать вывод, что сколь угодно значимой разницы между группами нет.
#
# Но если считать, что **любая** разница между группами есть повод для «разделения» классов, то я бы сделал такой вывод: кредитополучатели без детей являются более ответственными, чем клиенты, у которых есть дети. Видимо, наличие ребенка накладывает на клиента дополнительные финансовое бремя (обязательства) и клиенты либо менее ответственно относятся к своим кредитным обязательствам, либо не имеют возможности в срок оплачивать обязательства.
#
# Верно «пойман» и тот момент, что по некоторым группам заемщиков у нас недостаточно данных. Говорят, что выборка не сбалансирована, классы в выборке имеют разные размеры.
# </div>

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
'''data_relationship_family = data[['family_status', 'debt']]
data_relationship_family_d1 = data_relationship_family.loc[data_relationship_family['debt'] == 1][['family_status','debt']]
data_relationship_family_d1 = data_relationship_family_d1.groupby('family_status')['debt'].value_counts()
family_d1_frame = data_relationship_family_d1.to_frame()

data_relationship_family_d0 = data_relationship_family.loc[data_relationship_family['debt'] == 0][['family_status','debt']]
data_relationship_family_d0 = data_relationship_family_d0.groupby('family_status')['debt'].value_counts()
family_d0_frame = data_relationship_family_d0.to_frame()

debt_group_family = family_d0_frame.merge(family_d1_frame, on='family_status', how='left')
debt_group_family.rename(columns={'debt_x': 'задолж нет', 'debt_y': 'задолж есть'}, inplace=True)


def percent(row):
    row = row['задолж есть']/(row['задолж есть']+row['задолж нет'])*100
    return row

debt_group_family['% задолж'] = debt_group_family.apply(percent, axis = 1)

print(debt_group_family.sort_values(by = '% задолж', ascending=True))'''

# написал код через метод pivot_table и собственную функцию
import numpy as np
debt_group_family = pd.pivot_table(data, index=['family_status'], values=['debt'], aggfunc= ['count', np.sum])

def percent(row): # объявил функцию для подлсчета процента задолженности по кредитам
    row = (row['sum']/row['count'])*100
    return row
debt_group_family['% задолж'] = debt_group_family.apply(percent, axis = 1)
print(debt_group_family.sort_values(by = '% задолж', ascending=True))
# Out:
#                        count  sum  % задолж
#                         debt debt
# family_status
# вдовец / вдова           951   63  6.624606
# в разводе               1189   84  7.064760
# женат / замужем        12261  927  7.560558
# гражданский брак        4134  385  9.313014
# Не женат / не замужем   2796  273  9.763948

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Максим, код я понимаю тот же самый, с небольшими модификациями по названию столбцов?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='black'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='black'>Привет Александр! <br /> Большое спасибо за развернутые комментарии к моей работе! При написании кода я видел, что он не оптимальный, но запутался как использовать функцию pivot_table. <br />
#         Да, первый вариант кода был тот же, я переименовывал названия переменных и обращался к другим столбцам.
#         Но сейчас сделал через функцию pivot_table. Пока что для расчёта процентов мне пришлось объявить собственную функцию PERCENT и через метод apply добавить еще один столбец к созданной таблице. <br />Мне кажется, что расчёт процентов можно добавить через тип операции aggfunc=[] метода pivot_table, но я не нашёл как это можно сделать.<br /> Подскажи, можно ли в aggfunc запихнуть расчёт процента?
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **Мне кажется, что расчёт процентов можно добавить через тип операции aggfunc=[] метода pivot_table, но я не нашёл как это можно сделать. Подскажи, можно ли в aggfunc запихнуть расчёт процента?** - Максим, aggfunc у groupby может принимать в качестве аргумента любую пользовательскую функцию при условии, что она (функция) "знает", как интерпретировать массив значений pandas и возвращать одно значение. Aggfunc у groupby - это функция, которая принимает несколько отдельных значений и возвращает сводные данные.
#
# Статья с описанием этого как раз и находится на рекомендуемом мной ресурсе. Точная ссылка: https://dfedorov.spb.ru/pandas/Подробное%20руководство%20по%20группировке%20и%20агрегированию%20с%20помощью%20pandas.html (примерно в первой трети, раздел "Пользовательские функции").
#
# Однако, судя по описанию aggfunc у pivot_table здесь: https://dfedorov.spb.ru/pandas/Сводная%20таблица%20в%20pandas.html, то у сводной таблицу функция аггрегации определяет что делать с **повторяющимися** значениями.
# </div>

# %% [markdown]
# **Вывод:** на основании полученных данных можно сделать вывод, что зависимость между семейным положением и возвратом кредита в срок имеется. Вдовец/вдова чаще возвращают кредит вовремя, чем неженатые, или те, кто находится в гражданском браке.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь также верно. Кредитному отделу следует с осторожностью относиться к клиентам, которые не состоят или не состояли в браке. Согласно данным такие клиенты менее ответственные. Получается, что узаконенные отношения ведут к более ответственному отношению к своим обязательствам. Ну вроде как совпадает со здравым смыслом - семейные люди более скрупулёзно берегут свой семейное спокойствие и несут за него ответственность.
# </div>

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
'''data_relationship_income = data[['total_income_category', 'debt']]
data_relationship_income_d1 = data_relationship_income.loc[data_relationship_income['debt'] == 1][['total_income_category','debt']]
data_relationship_income_d1 = data_relationship_income_d1.groupby('total_income_category')['debt'].value_counts()
income_d1_frame = data_relationship_income_d1.to_frame()

data_relationship_income_d0 = data_relationship_income.loc[data_relationship_income['debt'] == 0][['total_income_category','debt']]
data_relationship_income_d0 = data_relationship_income_d0.groupby('total_income_category')['debt'].value_counts()
income_d0_frame = data_relationship_income_d0.to_frame()

debt_group_income = income_d0_frame.merge(income_d1_frame, on='total_income_category', how='left')
debt_group_income.rename(columns={'debt_x': 'задолж нет', 'debt_y': 'задолж есть'}, inplace=True)
debt_group_income = debt_group_income.fillna(0)
debt_group_income['задолж есть'] = debt_group_income[['задолж есть']].astype(int)


def percent(row):
    row = row['задолж есть']/(row['задолж есть']+row['задолж нет'])*100
    return row

debt_group_income['% задолж'] = debt_group_income.apply(percent, axis = 1)

print(debt_group_income.sort_values(by = '% задолж', ascending=True))'''

#(первая строка кода) группируешь детей (children) по столбцу долг (debt)
#агрегируешь долг по 2м функциям sum (здесь будут задолжники по соответствующей группе) и count (здесь будут все взявшие кредит в этой группе)

data_relationship_income = data.groupby('total_income_category')['debt'].agg(['sum', 'count'])

#(вторая строка кода) делить всех в группе на должников в группе - получаешь процент задолжников
#data_relationship_income_1 = (data_relationship_income['sum']/data_relationship_income['count'])*100
#data_relationship_income['percent'] = data_relationship_income.apply(data_relationship_income_1, axis=1)

def percent(row): # объявил функцию для подлсчета процента задолженности по кредитам
    row = (row['sum']/row['count'])*100
    return row
data_relationship_income['% задолж'] = data_relationship_income.apply(percent, axis = 1)

print(data_relationship_income.sort_values(by = '% задолж', ascending=True))
# Out:
#                         sum  count  % задолж
# total_income_category
# D                        21    349  6.017192
# B                       354   5014  7.060231
# A                         2     25  8.000000
# C                      1353  15921  8.498210
# E                         2     22  9.090909

# %% [markdown]
# **Вывод:** Здесь видно, что заемщики с категорией дохода D (доход от 30001 до 50000 у.е.) более добросовестные, чем заемщики категории C (доход от 50001 до 200000 у.е.). Из всей выборки, реже всего возвращают кредит вовремя заемщики с самыми низкими доходами (от 0 до 30000 у.е.), но делать выводы о большом риске невозврата при выдаче кредитов нельзя из-за маленькой выборки - всего 22 человека, против категорий В или С. Точно такая же ситуация и с категорией А - всего 25 человек.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# На мой взгляд - это самый сложный вопрос (для интерпретации результатов) в этом проекте.
#
# Посмотри на мой вывод, как дополнительный, альтернативный вариант твоему: исходя из здравого смысла логично предположить, что чаще всего должниками становятся люди с небольшим доходом, которым финансовые проблемы не позволяют вовремя осуществлять платежи. Но глядя на наши результаты лично мой вывод таков: выборка по заемщикам, как с наименьшим доходом, так и с наибольшим крайне недостаточна для формирования однозначных выводов. Можно думать, что E-категория самая низкооплачиваемая не может корректно распоряжаться деньгами и «влезает» в кредиты, но тогда неясно почему у А-категории также достаточно высокий процент задолженности. В общем вывод по группам А и Е неочевиден, мало данных.
#
# Если же взять для анализа только группы В, С и D, то по полученным данным не наблюдаем зависимости "те, кто получает больше ЗП, лучше возвращает кредит». В целом это логично, так как материальный достаток - не единственная переменная, которая влияет на качество кредитной истории.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='black'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='black'>
#         В этой задаче я попытался использовать предложенный тобой метод решения через groupby() и agg(), но
#        <br /> "(вторая строка кода) делить всех в группе на должников в группе - получаешь процент задолжников" <br /> у меня не получилось присоединить к основной таблице через метод apply(). А как ещё его присоединить к таблице, не догадался. Хотя чувствую, что ответ прост :)
#         <br />Подскажи пожалуйста, в чем была ошибка в моем коде?<br />
#         data_relationship_income_1 = (data_relationship_income['sum']/data_relationship_income['count'])*100
# data_relationship_income['percent'] = data_relationship_income.apply(data_relationship_income_1, axis=1)
#             </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Максим - беру твой код и комментирую его ниже:
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. НАЧАЛО**</b></div>

# %%
# здесь ты в новый датафрейм data_relationship_income "кладешь" результат группировки по total_income_category столбца 
# debt к которому применяешь 2 функции (sum и count). Тут всё верно

data_relationship_income = data.groupby('total_income_category')['debt'].agg(['sum', 'count'])

data_relationship_income
# Out:
#                         sum  count
# total_income_category
# A                         2     25
# B                       354   5014
# C                      1353  15921
# D                        21    349
# E                         2     22

# %%
# верна и эта строка, в которой ты формируешь ещё один, новый series - data_relationship_income_1 (и это лишний шаг), который 
# содержит отношение sum к count из столбцов предыдущего датафрейма. И этот series как раз и содержит требуемый результат.
# Посмотри на цифры и убедись сам. Всё, результат достигнут.

data_relationship_income_1 = (data_relationship_income['sum']/data_relationship_income['count'])*100

data_relationship_income_1

# А вот что происходит здесь мне не очень понятно. Здесь как будто-бы ты хочешь в первом софрмированном датафрейме создать
# столбец percent, который должен содержать значения из data_relationship_income к которым применена функция
# data_relationship_income_1. Но по факту data_relationship_income_1 не есть функция. Её можно определить либо через def,
# дибо через lambda-функцию и передать в agg так, как написано тут: 
# https://dfedorov.spb.ru/pandas/Подробное%20руководство%20по%20группировке%20и%20агрегированию%20с%20помощью%20pandas.html

#data_relationship_income['percent'] = data_relationship_income.apply(data_relationship_income_1, axis=1)
# Out:
# total_income_category
# A    8.000000
# B    7.060231
# C    8.498210
# D    6.017192
# E    9.090909
# dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. КОНЕЦ**</b></div>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
'''data_relationship_purpose = data[['purpose_category', 'debt']]
data_relationship_purpose_d1 = data_relationship_purpose.loc[data_relationship_purpose['debt'] == 1][['purpose_category','debt']]
data_relationship_purpose_d1 = data_relationship_purpose_d1.groupby('purpose_category')['debt'].value_counts()
purpose_d1_frame = data_relationship_purpose_d1.to_frame()

data_relationship_purpose_d0 = data_relationship_purpose.loc[data_relationship_purpose['debt'] == 0][['purpose_category','debt']]
data_relationship_purpose_d0 = data_relationship_purpose_d0.groupby('purpose_category')['debt'].value_counts()
purpose_d0_frame = data_relationship_purpose_d0.to_frame()

debt_group_purpose = purpose_d0_frame.merge(purpose_d1_frame, on='purpose_category', how='left')
debt_group_purpose.rename(columns={'debt_x': 'задолж нет', 'debt_y': 'задолж есть'}, inplace=True)
debt_group_purpose = debt_group_purpose.fillna(0)
debt_group_purpose['задолж есть'] = debt_group_purpose[['задолж есть']].astype(int)


def percent(row):
    row = row['задолж есть']/(row['задолж есть']+row['задолж нет'])*100
    return row

debt_group_purpose['% задолж'] = debt_group_purpose.apply(percent, axis = 1)

print(debt_group_purpose.sort_values(by = '% задолж', ascending=True))'''


import numpy as np
debt_group_purpose = pd.pivot_table(data, index=['purpose_category'], values=['debt'], aggfunc= ['count', np.sum])

def percent(row): # объявил функцию для подлсчета процента задолженности по кредитам
    row = (row['sum']/row['count'])*100
    return row
debt_group_purpose['% задолж'] = debt_group_purpose.apply(percent, axis = 1)
print(debt_group_purpose.sort_values(by = '% задолж', ascending=True))
# Out:
#                           count  sum  % задолж
#                            debt debt
# purpose_category
# операции с недвижимостью  10751  780  7.255139
# проведение свадьбы         2313  183  7.911803
# получение образования      3988  369  9.252758
# операции с автомобилем     4279  400  9.347978

# %% [markdown]
# **Вывод:** Все кредиты, попавшие в категорию "операции с недвижимостью" чаще погашаются в срок. Вероятно, это связано с более тщательным отбором заемщиков, большим количеством необходимых для этого документов и включением поручителей в условия договора.
# Кредиты на автомобиль чаще платятся не в срок.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Всё подтверждается и цифрами, и здравым смыслом. Машины люди покупают в кредит гораздо дорогие, нежели могут соответствовать им своим доходом (ну кому не хочется красивую иномарку). А вот рисковать ипотечным жильём люди не хотят. Интересно конечно, что с образованием не так - как правило такие кредиты берут люди мотивированные, имеющие цель впереди, да и суммы таких кредитов судя по рынку онлайн образования не так велики.
# </div>

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:* В проекте были пропуски по двум столбцам - общий доход и общее количество проработанных дней.
# Данные столбцы для принятия решения о выдаче кредита являются существенными и работники банка, при заполнении анкеты обратят внимание на такие данные в первую очередь. Например, без общего дохода невозможно рассчитать кредитную нагрузку заемщика и  сумму кредита, которую можно выдать без риска его просрочки. Считаю, что причина появления пропусков данных это техническая ошибка.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, молодец! Действительно, в наших данных пропуски в столбцах "трудовой стаж" и "ежемесячный доход" абсолютно идентичны. И первое, что приходит в случае, когда количество пропусков совпадает с точностью до единицы – некий сбой либо во время выгрузке данных на анализ, либо при объединении данных в единый файл, который также должен был передаваться на анализ, либо эти данные не собирались.
# </div>

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:* Так как медиана - это серединное значение из всей выборки количественных переменных, то она игнорирует возможные статистические выбросы, будь то экстремально низкие или высокие значения.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Да, в случае, если в данных наблюдаются "выбросы", то даже небольшое их количество может сильно "перетягивать" среднее значение в большую или меньшую сторону. Медиана зачастую даёт более правдивую картину. В общем случае, в реальных "живых" проектах я рекомендую в каждом случае смотреть на то, как распределены данные.
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Подводя итог всего исследования, можно сказать, что на основании данных можно строить скоринговую модель для заказчика.
# Идальный заемщик выглядит так - это бездетный вдовец, с доходом от 30001 до 50000 у.е., который берет кредит на покупку жилья.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий 👉</b>
#
# Финальный вывод конечно нужно более детальным сделать. Общий вывод - это изюминка твоей работы. Большинство заказчиков посмотрят сначала его (а некоторые только его). Чтобы выводы не огорошивали заказчика своей очевидностью, стоит добавить в них цифр, выводов, коэффициентов корреляций, графиков. Сделай так, чтобы вся найденная в данных информация была отражена в выводе.
#
# Твои, как аналитика, выводы - это данные ("алмаз"), которые родились из большого объёма неструктурированной, зачастую, казалось бы, несвязанной между собой информации ("горной породы").
#
# Для "не специалиста", поверь, выводы, которые ты делаешь будут казаться чем-то сродни волшебства. Эти люди "не специалисты" не будут понимать, НУ КАК ВОТ из наших табличек с кредитами можно было достать выводы, для того, чтобы спрогнозировать возврат/невозврат кредита.
#
# Но то, что они не понимают всего процесса - это не их беда. Просто они работают по-другому и мыслят другими категориями. Под "этими людьми" я здесь имею в виду топ-менеджеров, генеральных директоров и может быть ещё более высокий уровень. Их уровень понимания - это красивая и понятная им презентация в PowerPoint, с графиками бизнес показателей, с цифрами. Презентация из 3-5-10 слайдов это твоя, как аналитика "лебединая песня", те "алмазы", которые получены и облечены в ту форму, которая позволит лицам, принимающим решения принять такие зачастую многомилионной стоимости решения, которые напрямую повлияют на тот бизнес в котором ты работаешь.
# Возможный пример вывода - в виде скрина:
#
# ![image.png](attachment:image.png)</div>

# %% [markdown]
# ### Общий вывод:
#    #### Исходные данные:
#    **Заказчик** - кредитный отдел банка;
#    **Цель** - провести иследование на предмет влияния различных факторов на факт погашения кредита в срок;
#    **Таблица** - статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
# ***
#
# Перед началом исследования были поставлены следующие гипотезы:
# 1.Есть ли зависимость между количеством детей и возвратом кредита в срок?
# 2.Есть ли зависимость между семейным положением и возвратом кредита в срок?
# 3.Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# 4.Как разные цели кредита влияют на его возврат в срок?
#
# **Гипотеза 1 подтверждена частично.** *Для подтверждения гипотезы для заемщиков с 4 и более детьми необходимо больше данных.*
#
# Доля просроченных кредитов для заемщиков:
# без детей - 7.5%
# с тремя детьми - 8.1%
# с одним ребенком - 9.2%
# с двумя детьми - 9.4%
#
# **Вывод по гипотезе 1:**
# Люди у которых нет детей допускают просрочку кредита реже, чем те, у кого они есть.
#
# **Гипотеза 2 подтверждена.**
#
# Вдовцы более чем на 3% чаще отдают кредит в срок, чем те, кто не женат/не замужем.
# Доля просроченных кредитов взависимости от семейного положения:
# вдовец / вдова - 6.6%
# в разводе - 7%
# женат / замужем - 7.5%
# гражданский брак - 9.3%
# Не женат / не замужем - 9.7%
#
# **Вывод по гипотезе 2:**
# Люди, не состоящие в семейных отношениях чаще склонны нарушать сроки возврата кредита.
#
# **Гипотеза 3 подтверждена частично.**  *Для подтверждения гипотезы для заемщиков категорий А и Е необходимо больше данных.*
#
# Просрочка у заемщиков категории D на 2,4% ниже, чем у заемщиков категории С.
#
# Доля просроченных кредитов взависимости от категории дохода:
# D (доход от 30001 до 50000) - 6%
# B (доход от 200001 до 1000000) - 7%
# C (доход от 50001 до 200000) - 8.4%
#
# **Вывод по гипотезе 3:**
# Для подтверждения гипотезы необходим больший объем данных.
#
# **Гипотеза 4 подтверждена.**
#
# Доля просроченных кредитов взависимости от целей получения кредита:
# операции с недвижимостью - 7.2%
# проведение свадьбы - 7.9%
# получение образования - 9.2%
# операции с автомобилем - 9.3%
#
# **Вывод по гипотезе 4:**
#
# Кредиты, попавшие в категорию "операции с недвижимостью" чаще погашаются в срок. Вероятно, это связано с более тщательным отбором заемщиков, большим количеством необходимых для этого документов и включением поручителей в условия договора.
# При этом, разница между минимальной и максимальной долей просрочки по кредитам составляет всего 2.1%. Фактор цели кредита не обладает основным при принятии решения о его одобрении.
#
# ***
# #### Общие рекомендации: ####
# 1. При реализации скорингового алгоритма, можно опираться на семейное положение заёмщика и цель его кредита.
# 2. Для построения более точной модели кредитного скоринга, необходимо собрать больше данных по пунктам уровня дохода заемщиков и количества их детей.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='black'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='black'> Спасибо за то, что дал ссылки на изучение дополнительных материалов!
#           <br /> У меня дедлайн сегодня, так как завтра начинается новый модуль, поэтому хочу попросить тебя проверить материал в понедельник, чтобы в случае чего я успел исправить недочеты
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Максим, сейчас по факту приёма твоего проекта я тебе ещё пришлю дополнительных материалов (письмо в почту придёт).</div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Использование механизмов группировки данных (groupby - твой вариант) и создания сводных таблиц (pivot_table - он тоже в этом проекте возможен) является рекомендуемым и обязательным в работе любого аналитика данных и любого проекта. Ты показываешь владение этим инструментом.
#
# Для экспертного совершенствования в использовании groupby, понимании расширенных концептов использования pivot_table, crosstab и далее я очень рекомендую тебе обратить внимание на следующий ресурс: https://dfedorov.spb.ru/pandas/. Рекомендуемые темы/уроки для освоения тем выше - на скрине ниже.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что можно (и желательно прямо в этом проекте) сделать по-другому, доработать.
#
# И всего один момент, который не позволяет мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Финальный вывод в таком виде - это не то, что заказчик ждет от аналитика данных. Профессионал обязан предоставить точные, четкие и корректные **прогнозы и рекомендации**, которые помогут твоей компании в реализации скорингового алгоритма. Здесь, в финальном выводе требуется максимально подробно и с цифрами описать все те инсайды в данных, которые были обнаружены в ходе выполнения проекта.</div>
#
# Этот момент требует твоего внимания. Комментарий помечен красным цветом.
#
# Подводя итог: отличная работа на самом-то деле, молодец! Уверен, что исправление вывода не вызовет у тебя сложностей. Жду доработанную версию проекта на повторное ревью.
#
# ![image.png](attachment:image.png)
